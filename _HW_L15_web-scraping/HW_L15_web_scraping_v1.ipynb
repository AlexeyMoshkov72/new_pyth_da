# %% [markdown]
# ## Домашнее задание к лекции "Основы веб-скрапинга и работы с API"

# %% [markdown]
# ### Задание 1.
#
# #### Обязательная часть
# Будем парсить страницу со свежеми новостям на habr.com/ru/all/.
#
# Вам необходимо собирать только те статьи, в которых встречается хотя бы одно требуемое ключевое слово. Эти слова определяем в начале кода в переменной, например:
#
# KEYWORDS = ['python', 'парсинг']
#
# Поиск вести по всей доступной preview-информации (это информация, доступная непосредственно с текущей страницы).
#
# В итоге должен формироваться датафрейм вида: <дата> - <заголовок> - <ссылка>

# %%
import requests

import time

import pandas as pd

import datetime

# %%
KEYWORDS = ['python', 'парсинг', 'IT', 'код']

# %%
from bs4 import BeautifulSoup

# %%
def change_str_habr_date(str_date):
    import datetime
    
    months = {'1':'января', '2':'февраля','3':'марта','4':'апреля','5':'мая','6':'июня','7':'июля','8':'августа','9':'сентября','10':'октября','11':'ноября','12':'декабря'}
    date_1 = 'сегодня'
    date_2 = 'вчера'
    
    if date_1 in str_date:
        time = datetime.datetime.strptime(str_date, 'сегодня в %H:%M').time()
        date = datetime.datetime.today().date()
        date_post = datetime.datetime.combine(date, time)
    elif date_2 in str_date:
        time = datetime.datetime.strptime(str_date, 'вчера в %H:%M').time()
        date = datetime.datetime.now().date() - datetime.timedelta(days=1) 
        date_post = datetime.datetime.combine(date, time)
    else:
        for key, values in months.items():
            if values in str_date:
                str_date = str_date.replace(values, key)
                date_post = datetime.datetime.strptime(str_date, '%d %m %Y в %H:%M')
    
    return date_post

# %%
URL = 'https://habr.com/ru/all/'
res = requests.get(URL)
soup = BeautifulSoup(res.text, 'html.parser')
posts = soup.find_all('article', class_='post')

row = dict()
habr_news = pd.DataFrame()

for post in posts:
    time.sleep(0.3)
    post_class_link = post.find('h2', class_='post__title')
    post_link =  post_class_link.find('a').get('href')
    title_post = post_class_link.text.strip()
    text_preview = post.find('div', class_='post__text').text
    text_date = post.find('span', class_='post__time').text
    date = change_str_habr_date(text_date)
    for word in KEYWORDS:
        if word in title_post or word in text_preview:
            row = {'date': date, 'title':title_post, 'link':post_link}
            habr_news = pd.concat([habr_news, pd.DataFrame([row])])

habr_news
# Out:
#                  date                                              title  \
# 0 2020-12-09 10:21:00       cGit-UI — web-интерфейс для Git-репозиториев
# 0 2020-12-09 09:09:00  Intel ControlFlag — система машинной отладки ч...
# 0 2020-12-09 03:06:00              Изучаю Scala: Часть 5 — Http Requests
# 0 2020-12-08 22:29:00  Связные списки, трюки с указателями и хороший ...
# 0 2020-12-08 19:13:00  Клиент-серверный IPC при помощи Python multipr...
# 0 2020-12-08 18:12:00  Конференция Demo Day — новое образовательное м...
#
#                                              link
# 0                https://habr.com/ru/post/531930/
# 0  https://habr.com/ru/company/intel/blog/531862/
# 0                https://habr.com/ru/post/531548/
# 0                https://habr.com/ru/post/532004/
# 0                https://habr.com/ru/post/531994/
# 0   https://habr.com/ru/company/otus/blog/531984/

# %% [markdown]
# #### Дополнительная часть (необязательная)
#
# Улучшить скрипт так, чтобы он анализировал не только preview-информацию статьи, но и весь текст статьи целиком.
#
# Для этого потребуется получать страницы статей и искать по тексту внутри этой страницы.
#
# Итоговый датафрейм формировать со столбцами: <дата> - <заголовок> - <ссылка> - <текст_статьи>

# %%
# получаем часть HTML кода по ссылке (переменная post_link)

# soup_for_full_text = BeautifulSoup(requests.get(post_link).text, 'html.parser')
# soup_for_full

# %%
row_full = dict()
habr_news_full = pd.DataFrame()

for post in posts:
    time.sleep(0.3)
    post_class_link = post.find('h2', class_='post__title')
    post_link =  post_class_link.find('a').get('href')
    title_post = post_class_link.text.strip()
    soup_for_full_text = BeautifulSoup(requests.get(post_link).text, 'html.parser')
    text = soup_for_full_text.find('div', class_='post__text').text.strip()
    text_date = post.find('span', class_='post__time').text
    date = change_str_habr_date(text_date)
    for word in KEYWORDS:
        if word in title_post or word in text:
            row_full = {'date': date, 'title':title_post, 'link':post_link,  'text':text}
            habr_news_full = pd.concat([habr_news_full, pd.DataFrame([row_full])])

            
habr_news_full.drop_duplicates(subset=['link'], keep=False)
# Out:
#                  date                                              title  \
# 0 2020-12-09 10:29:00            Советские шифры во Второй Мировой войне
# 0 2020-12-09 10:21:00       cGit-UI — web-интерфейс для Git-репозиториев
# 0 2020-12-09 09:12:00                  Создаём модчипы для PlayStation 1
# 0 2020-12-09 08:33:00  Ловец идей, почти хакатон, или как быстро прок...
# 0 2020-12-09 03:51:00    Конфигурируем сервис с помощью Vault и Pydantic
# 0 2020-12-09 03:06:00              Изучаю Scala: Часть 5 — Http Requests
# 0 2020-12-08 22:29:00  Связные списки, трюки с указателями и хороший ...
# 0 2020-12-08 20:27:00  Новая версия командного интерпретатора GNU Bas...
# 0 2020-12-08 19:13:00  Клиент-серверный IPC при помощи Python multipr...
# 0 2020-12-08 19:10:00  Интеграция чат-бота Dialogflow с Angular-прило...
# 0 2020-12-08 19:00:00  Как обратиться к человеку на английском, чтобы...
# 0 2020-12-08 18:42:00  Война со скрытыми алгоритмами, заманивающими в...
# 0 2020-12-08 18:36:00  Почему не стоит пытаться ускорять разработку п...
# 0 2020-12-08 17:35:00         Frida изучаем эксплуатацию алгоритмов Heap
#
#                                                 link  \
# 0                   https://habr.com/ru/post/532044/
# 0                   https://habr.com/ru/post/531930/
# 0                   https://habr.com/ru/post/531072/
# 0                   https://habr.com/ru/post/532036/
# 0                   https://habr.com/ru/post/532032/
# 0                   https://habr.com/ru/post/531548/
# 0                   https://habr.com/ru/post/532004/
# 0  https://habr.com/ru/company/selectel/blog/532002/
# 0                   https://habr.com/ru/post/531994/
# 0     https://habr.com/ru/company/ruvds/blog/530940/
# 0  https://habr.com/ru/company/englishdom/blog/53...
# 0  https://habr.com/ru/company/skillfactory/blog/...
# 0                   https://habr.com/ru/post/531990/
# 0      https://habr.com/ru/company/otus/blog/531970/
#
#                                                 text
# 0  ПредисловиеС изобретением Александром Поповым ...
# 0  cGit-ui — это web-интерфейс для Git-репозитори...
# 0  В детстве у меня была PlayStation 1 (PS1). Одн...
# 0  Итак, дано: команда разработки чуть больше 50 ...
# 0  Предисловие\nВ данной статье я расскажу о конф...
# 0  Привет, Хабр! Продолжаю изучать Scala. Большин...
# 0  В интервью на TED 2016 (14:10) Линус Торвальдс...
# 0  Сегодня стало известно о выходе новой версии к...
# 0  Статья отражает личный опыт разработки CLI при...
# 0  Существует множество публикаций о разработке ч...
# 0  С вопросом корректности в англоязычных странах...
# 0  Привет Хабр! Делюсь с вами постом, в котором р...
# 0  Если вам приходилось руководить разработкой пр...
# 0  Эксперт OTUS — Александр Колесников поделился ...

# %% [markdown]
# ### Задание 2.
#
# #### Обязательная часть
#
# Написать скрипт, который будет проверять список e-mail адресов на утечку при помощи сервиса Avast Hack Ckeck. Список email-ов задаем переменной в начале кода:
# EMAIL = [xxx@x.ru, yyy@y.com]
#
# В итоге должен формироваться датафрейм со столбцами: <почта> - <дата утечки> - <источник утечки> - <описание утечки>
#
# Подсказка: сервис работает при помощи "скрытого" API. Внимательно изучите post-запросы.

# %%
import json

# %%
URL_1 = 'https://identityprotection.avast.com/v1/web/query/site-breaches/unauthorized-data'
headers = {'Vaar-Version': '0', 'Vaar-Header-App-Product':'hackcheck-web-avast'}

# %%
emailAddresses = ['amoshkov@mail.ru', 'aamoshkov@gmail.com']
dict_data = dict()
dict_data['emailAddresses'] = emailAddresses

# %%
data = json.dumps(dict_data)

# %%
res = requests.post(URL_1, json=dict_data, headers=headers)
dict_res = res.json()

# %%
dict_res
# Out:
# {'breaches': {'133': {'breachId': 133,
#    'site': 'vedomosti.ru',
#    'recordsCount': 217882,
#    'description': "In May 2012, Russian business newspaper Vedomosti had its domain's user database breached by an unknown actor. It wasn't until four years later that the actor began sharing the database with private parties.",
#    'publishDate': '2016-12-15T00:00:00Z',
#    'statistics': {'usernames': 0, 'passwords': 204328, 'emails': 217854}},
#   '14357': {'breachId': 14357,
#    'site': 'storelp.ru',
#    'recordsCount': 1435760,
#    'description': "At an unconfirmed date, StoreLP.ru's database was allegedly breached. The stolen data contains passwords and email addresses. This breach is being privately shared on the internet.",
#    'publishDate': '2018-06-19T00:00:00Z',
#    'statistics': {'usernames': 0, 'passwords': 1435760, 'emails': 1435760}},
#   '3701': {'breachId': 3701,
#    'site': 'fc-zenit.ru',
#    'recordsCount': 90330,
#    'description': "In July 2010, FC Zenit's user database was allegedly breached. The stolen data contains over 90,000 records including email addresses and passwords. The compromised data is being shared privately on the darknet.",
#    'publishDate': '2017-03-31T00:00:00Z',
#    'statistics': {'usernames': 0, 'passwords': 90330, 'emails': 90330}}},
#  'data': {'fc-zenit.ru': {'amoshkov@mail.ru': [{'breachId': 3701,
#      'usernameBreached': True,
#      'passwordBreached': True}]},
#   'vedomosti.ru': {'amoshkov@mail.ru': [{'breachId': 133,
#      'usernameBreached': True,
#      'passwordBreached': True}]},
#   'storelp.ru': {'amoshkov@mail.ru': [{'breachId': 14357,
#      'usernameBreached': True,
#      'passwordBreached': True}]}},
#  'summary': {'amoshkov@mail.ru': {'breaches': [133, 14357, 3701]},
#   'aamoshkov@gmail.com': {'breaches': []}}}

# %%
leak_email = pd.DataFrame()

for email in emailAddresses:
    k = len(dict_res['summary'][f'{email}']['breaches'])
    for i in range(k):
        a = dict_res['summary'][f'{email}']['breaches'][i]
        site = dict_res['breaches'][f'{a}']['site']
        text = dict_res['breaches'][f'{a}']['description']
        date = dict_res['breaches'][f'{a}']['publishDate']
        row = {'email': email, 'date': date, 'source':site, 'description': text}
        leak_email = pd.concat([leak_email, pd.DataFrame([row])])
        
        
leak_email
# Out:
#               email                  date        source  \
# 0  amoshkov@mail.ru  2020-05-21T00:00:00Z        vk.com
# 0  amoshkov@mail.ru  2016-12-15T00:00:00Z  vedomosti.ru
# 0  amoshkov@mail.ru  2018-06-19T00:00:00Z    storelp.ru
# 0  amoshkov@mail.ru  2020-07-16T00:00:00Z       unknown
# 0  amoshkov@mail.ru  2017-03-31T00:00:00Z   fc-zenit.ru
#
#                                          description
# 0  At some time in 2020, the Russian social netwo...
# 0  In May 2012, Russian business newspaper Vedomo...
# 0  At an unconfirmed date, StoreLP.ru's database ...
# 0  At an unconfirmed date, data purportedly assoc...
# 0  In July 2010, FC Zenit's user database was all...

# %% [markdown]
# #### Дополнительная часть (необязательная)
#
# Написать скрипт, который будет получать 50 последних постов указанной группы во Вконтакте.
# Документация к API VK: https://vk.com/dev/methods , вам поможет метод wall.get
#
# GROUP = 'netology'
# TOKEN = УДАЛЯЙТЕ В ВЕРСИИ ДЛЯ ПРОВЕРКИ, НА GITHUB НЕ ВЫКЛАДЫВАТЬ
# В итоге должен формироваться датафрейм со столбцами: <дата поста> - <текст поста>
#
# #### ПРИМЕЧАНИЕ
# Домашнее задание сдается ссылкой на репозиторий GitHub. Не сможем проверить или помочь, если вы пришлете:
#
# файлы;
# архивы;
# скриншоты кода.
# Все обсуждения и консультации по выполнению домашнего задания ведутся только на соответствующем канале в slack.

# %% [markdown]
# ##### Как правильно задавать вопросы аспирантам, преподавателям и коллегам?
#
# Прежде чем задать вопрос необходимо попробовать найти ответ самому в интернете. Навык самостоятельного поиска информации – один из важнейших, и каждый практикующий специалист любого уровня это делает каждый день.
#
# Любой вопрос должен быть сформулирован по алгоритму:
# 1) Что я делаю?
# 2) Какого результата я ожидаю?
# 3) Как фактический результат отличается от ожидаемого?
# 4) Что я уже попробовал сделать, чтобы исправить проблему?
#
# По возможности, прикрепляйте к вопросу скриншоты, либо ссылки на код. Оставляйте только проблемный и воспроизводимый участок кода, все решение выкладывать не допускается.
